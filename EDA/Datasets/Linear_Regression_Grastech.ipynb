# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("car_done.csv")

# %%
df
# Out:
#      Unnamed: 0 Manufacturer    Model  Sales_in_thousands  \
# 0             0        Acura  Integra              16.919
# 1             1        Acura       TL              39.384
# 2             2        Acura       CL              14.114
# 3             3        Acura       RL               8.588
# 4             4         Audi       A4              20.397
# ..          ...          ...      ...                 ...
# 152         152        Volvo      V40               3.545
# 153         153        Volvo      S70              15.245
# 154         154        Volvo      V70              17.531
# 155         155        Volvo      C70               3.493
# 156         156        Volvo      S80              18.969
#
#      four_year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                    16.360    Passenger               21.50          1.8
# 1                    19.875    Passenger               28.40          3.2
# 2                    18.225    Passenger                 NaN          3.2
# 3                    29.725    Passenger               42.00          3.5
# 4                    22.255    Passenger               23.99          1.8
# ..                      ...          ...                 ...          ...
# 152                     NaN    Passenger               24.40          1.9
# 153                     NaN    Passenger               27.50          2.4
# 154                     NaN    Passenger               28.80          2.4
# 155                     NaN    Passenger               45.50          2.3
# 156                     NaN    Passenger               36.00          2.9
#
#      Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# 0         140.0      101.2   67.3   172.4        2.639           13.2
# 1         225.0      108.1   70.3   192.9        3.517           17.2
# 2         225.0      106.9   70.6   192.0        3.470           17.2
# 3         210.0      114.6   71.4   196.6        3.850           18.0
# 4         150.0      102.6   68.2   178.0        2.998           16.4
# ..          ...        ...    ...     ...          ...            ...
# 152       160.0      100.5   67.6   176.6        3.042           15.8
# 153       168.0      104.9   69.3   185.9        3.208           17.9
# 154       168.0      104.9   69.3   186.2        3.259           17.9
# 155       236.0      104.9   71.5   185.7        3.601           18.5
# 156       201.0      109.9   72.1   189.8        3.600           21.1
#
#      Fuel_efficiency Latest_Launch  Power_perf_factor
# 0               28.0      2/2/2012          58.280150
# 1               25.0      6/3/2011          91.370778
# 2               26.0      1/4/2012                NaN
# 3               22.0     3/10/2011          91.389779
# 4               27.0     10/8/2011          62.777639
# ..               ...           ...                ...
# 152             25.0     9/21/2011          66.498812
# 153             25.0    11/24/2012          70.654495
# 154             25.0     6/25/2011          71.155978
# 155             23.0     4/26/2011         101.623357
# 156             24.0    11/14/2011          85.735655
#
# [157 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              157 non-null    int64
#  1   Manufacturer            157 non-null    object
#  2   Model                   157 non-null    object
#  3   Sales_in_thousands      157 non-null    float64
#  4   four_year_resale_value  121 non-null    float64
#  5   Vehicle_type            157 non-null    object
#  6   Price_in_thousands      155 non-null    float64
#  7   Engine_size             156 non-null    float64
#  8   Horsepower              156 non-null    float64
#  9   Wheelbase               156 non-null    float64
#  10  Width                   156 non-null    float64
#  11  Length                  156 non-null    float64
#  12  Curb_weight             155 non-null    float64
#  13  Fuel_capacity           156 non-null    float64
#  14  Fuel_efficiency         154 non-null    float64
#  15  Latest_Launch           157 non-null    object
#  16  Power_perf_factor       155 non-null    float64
# dtypes: float64(12), int64(1), object(4)
# memory usage: 21.0+ KB

# %%
#check the null values
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# Manufacturer               0
# Model                      0
# Sales_in_thousands         0
# four_year_resale_value    36
# Vehicle_type               0
# Price_in_thousands         2
# Engine_size                1
# Horsepower                 1
# Wheelbase                  1
# Width                      1
# Length                     1
# Curb_weight                2
# Fuel_capacity              1
# Fuel_efficiency            3
# Latest_Launch              0
# Power_perf_factor          2
# dtype: int64

# %%
#return the value count of the column
df["four_year_resale_value"].value_counts()
# Out:
# four_year_resale_value
# 18.225    2
# 12.025    2
# 7.750     2
# 16.575    2
# 16.360    1
#          ..
# 34.080    1
# 11.425    1
# 13.240    1
# 16.725    1
# 13.760    1
# Name: count, Length: 117, dtype: int64

# %%
print(df["four_year_resale_value"].describe())
print("median",df["four_year_resale_value"].median())
# Out:
# count    121.000000
# mean      18.072975
# std       11.453384
# min        5.160000
# 25%       11.260000
# 50%       14.180000
# 75%       19.875000
# max       67.550000
# Name: four_year_resale_value, dtype: float64
# median 14.18

# %%
df["four_year_resale_value"].fillna(value = df["four_year_resale_value"].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Manufacturer              0
# Model                     0
# Sales_in_thousands        0
# four_year_resale_value    0
# Vehicle_type              0
# Price_in_thousands        2
# Engine_size               1
# Horsepower                1
# Wheelbase                 1
# Width                     1
# Length                    1
# Curb_weight               2
# Fuel_capacity             1
# Fuel_efficiency           3
# Latest_Launch             0
# Power_perf_factor         2
# dtype: int64

# %%
df.ffill(inplace = True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Manufacturer              0
# Model                     0
# Sales_in_thousands        0
# four_year_resale_value    0
# Vehicle_type              0
# Price_in_thousands        0
# Engine_size               0
# Horsepower                0
# Wheelbase                 0
# Width                     0
# Length                    0
# Curb_weight               0
# Fuel_capacity             0
# Fuel_efficiency           0
# Latest_Launch             0
# Power_perf_factor         0
# dtype: int64

# %%
#return number of unique values in each column
df.nunique()
# Out:
# Unnamed: 0                157
# Manufacturer               30
# Model                     156
# Sales_in_thousands        157
# four_year_resale_value    117
# Vehicle_type                2
# Price_in_thousands        152
# Engine_size                31
# Horsepower                 66
# Wheelbase                  88
# Width                      78
# Length                    127
# Curb_weight               147
# Fuel_capacity              55
# Fuel_efficiency            20
# Latest_Launch             130
# Power_perf_factor         154
# dtype: int64

# %%
df.drop(columns="Unnamed: 0",inplace = True)

# %%
#print only columns
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'four_year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
#duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#return specific type of data types
df.select_dtypes([int,float]).columns
# Out:
# Index(['Sales_in_thousands', 'four_year_resale_value', 'Price_in_thousands',
#        'Engine_size', 'Horsepower', 'Wheelbase', 'Width', 'Length',
#        'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency', 'Power_perf_factor'],
#       dtype='object')

# %%
plt.boxplot(df["Sales_in_thousands"])
plt.show()

# %%
plt.boxplot(df["four_year_resale_value"])
plt.show()

# %%
plt.boxplot(df["Price_in_thousands"])
plt.show()

# %%
#outlier removal
def IQR(x):
    q1=x.quantile(0.25)
    q3=x.quantile(0.75)
    iqr=q3-q1
    lf=q1-(1.5*iqr)
    uf=q3+(1.5*iqr)
    print("LF",lf)
    print("UF",uf)

# %%
IQR(df["Sales_in_thousands"])
# Out:
# LF -66.649
# UF 148.719

# %%
df["Sales_in_thousands"] = np.where(df["Sales_in_thousands"]>148.719,148.719,df["Sales_in_thousands"])

# %%
IQR(df["four_year_resale_value"])
# Out:
# LF 4.152499999999998
# UF 26.532500000000002

# %%
df["four_year_resale_value"] = np.where(df["four_year_resale_value"]>26.5325,26.5325,df["four_year_resale_value"])

# %%
IQR(df["Price_in_thousands"])
# Out:
# LF -2.5325000000000024
# UF 52.6075

# %%
df["Price_in_thousands"] = np.where(df["Price_in_thousands"]>52.6075,52.6075,df["Price_in_thousands"])

# %%
plt.boxplot(df["Sales_in_thousands"])
plt.show()

# %%
plt.boxplot(df["four_year_resale_value"])
plt.show()

# %%
plt.boxplot(df["Price_in_thousands"])
plt.show()

# %%
IQR(df['Engine_size'])
# Out:
# LF 0.49999999999999956
# UF 5.300000000000001

# %%
df['Engine_size'] = np.where(df['Engine_size']>5.3,5.3,df['Engine_size'])

# %%
plt.boxplot(df['Engine_size'])
plt.show()

# %%
IQR(df["Horsepower"])
# Out:
# LF 52.5
# UF 312.5

# %%
df["Horsepower"] = np.where(df["Horsepower"]>312.5,312.5,df["Horsepower"])

# %%
plt.boxplot(df["Horsepower"])
plt.show()

# %%
IQR(df["Wheelbase"])
# Out:
# LF 89.19999999999999
# UF 126.0

# %%
df["Wheelbase"] = np.where(df["Wheelbase"]>126.0,126.0,df["Wheelbase"])

# %%
plt.boxplot(df["Wheelbase"])
plt.show()

# %%
IQR(df["Width"])
# Out:
# LF 60.750000000000014
# UF 81.14999999999999

# %%
df["Width"] = np.where(df["Width"]>81.1499,81.1499,df["Width"])

# %%
IQR(df["Length"])
# Out:
# LF 149.7
# UF 224.09999999999997

# %%
df["Length"] = np.where(df["Length"]>224.0999,224.0999,df["Length"])

# %%
IQR(df["Curb_weight"])
# Out:
# LF 1.706
# UF 5.09

# %%
df["Curb_weight"] = np.where(df["Curb_weight"]>5.09,5.09,df["Curb_weight"])

# %%
IQR(df["Fuel_capacity"])
# Out:
# LF 10.250000000000002
# UF 25.049999999999997

# %%
df["Fuel_capacity"] = np.where(df["Fuel_capacity"]>25.0499,25.0499,df["Fuel_capacity"])

# %%
IQR(df["Fuel_efficiency"])
# Out:
# LF 13.5
# UF 33.5

# %%
df["Fuel_efficiency"] = np.where(df["Fuel_efficiency"]>33.5,33.5,df["Fuel_efficiency"])

# %%
IQR(df["Power_perf_factor"])
# Out:
# LF 16.50106724999999
# UF 134.43807973000003

# %%
df["Power_perf_factor"] = np.where(df["Power_perf_factor"]>134.4380,134.4380,df["Power_perf_factor"])

# %%
import seaborn as sns
def outliers(x):
    y=x.select_dtypes(include=[int,float])
    for i in y:
        sns.boxplot(x=df[i])
        plt.title(i)
        plt.show()

# %%
outliers(df)

# %%
df["Manufacturer"].value_counts()
# Out:
# Manufacturer
# Ford          11
# Dodge         11
# Chevrolet      9
# Mercedes-B     9
# Toyota         9
# Chrysler       7
# Mitsubishi     7
# Nissan         7
# Mercury        6
# Oldsmobile     6
# Lexus          6
# Pontiac        6
# Volvo          6
# Volkswagen     6
# Cadillac       5
# Honda          5
# Saturn         5
# Plymouth       4
# Buick          4
# Acura          4
# Audi           3
# BMW            3
# Lincoln        3
# Porsche        3
# Jeep           3
# Hyundai        3
# Saab           2
# Subaru         2
# Jaguar         1
# Infiniti       1
# Name: count, dtype: int64

# %%
df["Manufacturer"].nunique()
# Out:
# 30

# %%
df["Model"].nunique()
# Out:
# 156

# %%
#Always remove date column in linear regression data set
#We use it in time series

# %%
df["Vehicle_type"].value_counts()
# Out:
# Vehicle_type
# Passenger    116
# Car           41
# Name: count, dtype: int64

# %%
df["Vehicle_type"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Vehicle_type'>

# %%
df["Vehicle_type"] = np.where(df["Vehicle_type"] == "Car",1,0)

# %%
df["Vehicle_type"].value_counts()
# Out:
# Vehicle_type
# 0    116
# 1     41
# Name: count, dtype: int64

# %%
df["Vehicle_type"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Vehicle_type'>

# %%
#Removes outlier with IQR(Inter Quartile Range  Q3--) formula
#Q3 is 75percentile if numerical column
#Box plot used to dispaly outliers
#Null is filled to determine the outliers

# %%
corf = df.select_dtypes(include = [int,float]).corr()
#correlation value -1 low correlated  to 1 highly correlated

# %%
sns.heatmap(corf)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (15,15))
sns.heatmap(corf,annot = True)
# Out:
# <Axes: >

# %%
plt.scatter(df["Horsepower"],df["Power_perf_factor"])
plt.xlabel("HP")
plt.ylabel("PPF")
plt.show()

# %%
plt.scatter(df["Curb_weight"],df["Fuel_efficiency"])
plt.xlabel("CW")
plt.ylabel("FE")
plt.show()

# %%
plt.scatter(df["Engine_size"],df["Fuel_efficiency"])
plt.xlabel("ES")
plt.ylabel("FE")
plt.show()

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'four_year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
x = df[[ 'four_year_resale_value',
       'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
       'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
       'Fuel_efficiency', 'Power_perf_factor']]              #Independent Values
y = df["Sales_in_thousands"]#Predicted value

# %%
from sklearn.model_selection import train_test_split as tts
#train data is always more than test
X_train,x_test,y_train,y_test = tts(x,y,test_size = 0.2,random_state = 44)
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train) #model fitting
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)        #R^2 varying between 29 to 45
#R^2 = coefficient of determination liniear model humare avg model se kitna accha perform kar rha hai
#R^2 = avg MSE- Linear MSE/Avg Model MSE
# Out:
# 0.3896306399924704

# %%
lr.predict(X_train)
# Out:
# array([ 62.14089294,  -6.24872966,  41.69115064, 120.90573898,
#         52.17570836,  34.37053996,  62.4481831 ,  62.38020288,
#         59.13116771,  77.00933208,  93.39757108,  41.30092533,
#         77.48147162,  62.31809863,  15.04447688,  -4.76852796,
#         72.70595488,  65.60509071,  40.41970491,  35.67060686,
#         50.21792467,  27.12783372,  71.05948201,  21.46456619,
#         14.36430778,  68.57032872, -17.5025384 ,  66.41299766,
#         55.37274961,  58.25345098,  16.4469761 ,  56.53520099,
#         -2.60928241,  19.83115586,  69.28158628,  47.13467441,
#         54.41124692,  74.96240285,  97.40377365,  43.79885345,
#         49.5397808 ,  58.69151741,  37.02594724,  18.4770769 ,
#         41.93103964,  49.85926605,  61.90403106,  29.23048466,
#         61.64156948,  63.38719313,  57.38724156,  72.08159182,
#         47.46219339,  58.27132546,  36.99995644,  30.01994495,
#         40.86750905, 106.27454822,  79.80883457,  38.08006941,
#         53.66123201,  57.63801745,  58.82589357,  64.49491964,
#        126.49195892,  54.34766223,  69.33771431, -16.867065  ,
#         25.17622901,  56.83990448, -24.96060049,  42.40854605,
#         23.77002967,  54.9781891 ,  61.32764025,  92.87653264,
#         97.13812364,  29.6928885 ,  56.21855785,  40.42231419,
#         55.16074005,  47.08839722,  28.59396227,  60.52784875,
#        111.5264394 ,   7.41680109,   9.71344809,  70.97128862,
#         16.31654882,  37.03617559,  51.58496084,  56.77758298,
#          8.36102684,  37.47193679,  21.155076  ,  36.37518387,
#         70.33987321,  34.32458973,  72.30555178,  65.48351091,
#         62.52598578,  58.86433088,  57.57893065,   8.3304098 ,
#         59.11756001,   9.52453218,  32.00699483,  30.88113156,
#          3.92228051,  44.36017643,  39.76588443,  40.87217442,
#         38.03036738,  67.83694106,  20.15895521,  53.18022698,
#         52.49930808, 124.39194803,  41.16652322,  28.43369467,
#         34.34759144, -18.61702153,  65.40551966,  53.92121007,
#         70.56434117])

# %%
pre = lr.predict(X_train)
actual  = y_train

# %%
error = actual -pre
mse = np.mean(np.square(error))
RMSE = np.sqrt(mse)

# %%
print("MSE",mse)
print("RMSE",RMSE)
# Out:
# MSE 1230.447753211114
# RMSE 35.07773871290899

# %%
from sklearn.metrics import mean_squared_error as mse, root_mean_squared_error as rmse

# %%
print("MSE",mse(actual,pre))
print("RMSE",rmse(actual,pre))
# Out:
# MSE 1230.447753211114
# RMSE 35.07773871290899

# %%
er = df["Sales_in_thousands"]-df["Sales_in_thousands"].mean()
avg_mse = np.mean(np.square(er))
avg_rmse = np.sqrt(avg_mse)                   # manual formaula

# %%
r2 = (avg_mse-mse)/avg_mse
print("R Square ",r2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-87-4252554946.py in <cell line: 0>()
# ----> 1 r2 = (avg_mse-mse)/avg_mse
#       2 print("R Square ",r2)
#
# TypeError: unsupported operand type(s) for -: 'float' and 'function'

# %%
er = y_train - lr.predict(X_train)
mse = np.mean(np.square(er))
rmse = np.sqrt(mse)

# %% [markdown]
# #Imporove R^2 Of Model

# %%
sns.distplot(np.log(df["Sales_in_thousands"]))
plt.show()

# %%
x = df[[ 'four_year_resale_value',
       'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
       'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
       'Fuel_efficiency', 'Power_perf_factor']]              #Independent Values
y = np.log1p(df["Sales_in_thousands"])#Predicted value

# %%
X_train,x_test,y_train,y_test = tts(x,y,test_size = 0.2,random_state = 60)

# %%
lr1 = LinearRegression()

# %%
lr1.fit(X_train,y_train)

# %%
lr1.score(X_train,y_train)
